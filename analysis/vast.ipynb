# %%
import pandas as pd

# %%
vast = pd.read_csv('../data/VAST/vast_test.csv')
vast
# Out:
#              author                                               post  \
# 0     Marcus Vitone  I totally agree with this premise. As a younge...
# 1     Marcus Vitone  I totally agree with this premise. As a younge...
# 2         bob parno  Who is the mayor of N.Y. to assume he has the ...
# 3         bob parno  Who is the mayor of N.Y. to assume he has the ...
# 4         bob parno  Who is the mayor of N.Y. to assume he has the ...
# ...             ...                                                ...
# 3001    Demosthenes  For a long time, it's been a role of Supreme C...
# 3002           Sage  What a ridiculously lopsided "debate". Suppose...
# 3003            CAE  Methinks none of the commentators have tried g...
# 3004            CAE  Methinks none of the commentators have tried g...
# 3005     Praesidius  Too often overlooked in these discussions is t...
#
#                 ori_topic   ori_id            new_topic  label  type_idx  \
# ...
